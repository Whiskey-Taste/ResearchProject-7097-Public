# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import re

file_path = '/content/drive/My Drive/FDA/'

# Read the dataset
reac_df = pd.read_csv(file_path+"REAC24Q4.txt", sep='$')
demo_df = pd.read_csv(file_path+"DEMO24Q4.txt", sep='$')
drug_df = pd.read_csv(file_path+"DRUG24Q4.txt", sep='$')
indi_df = pd.read_csv(file_path+"INDI24Q4.txt", sep='$')
outc_df = pd.read_csv(file_path+"OUTC24Q4.txt", sep='$')
rpsr_df = pd.read_csv(file_path+"RPSR24Q4.txt", sep='$')
ther_df = pd.read_csv(file_path+"THER24Q4.txt", sep='$')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <ipython-input-78-2d2311b22119>:11: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   demo_df = pd.read_csv(file_path+"DEMO24Q4.txt", sep='$')
# <ipython-input-78-2d2311b22119>:12: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   drug_df = pd.read_csv(file_path+"DRUG24Q4.txt", sep='$')

# %%
reac_df
# Out:
#          primaryid    caseid  \
# 0        100100247  10010024
# 1        100100247  10010024
# 2        100100247  10010024
# 3        100100247  10010024
# 4        100100247  10010024
# ...            ...       ...
# 1472745   99310703   9931070
# 1472746   99310703   9931070
# 1472747   99310743   9931074
# 1472748   99696784   9969678
# 1472749   99696784   9969678
#
#                                                         pt drug_rec_act
# 0                               Malignant melanoma stage I          NaN
# 1                                          Keratoacanthoma          NaN
# 2                                 Blood pressure increased          NaN
# 3                                          Keratoacanthoma          NaN
# 4                                           Hyperkeratosis          NaN
# ...                                                    ...          ...
# 1472745                         Liver transplant rejection          NaN
# 1472746       Post transplant lymphoproliferative disorder          NaN
# 1472747       Post transplant lymphoproliferative disorder          NaN
# 1472748  Drug reaction with eosinophilia and systemic s...          NaN
# 1472749                         Toxic epidermal necrolysis          NaN
#
# [1472750 rows x 4 columns]

# %%
demo_df
# Out:
#          primaryid    caseid  caseversion i_f_code    event_dt    mfr_dt  \
# 0        100100247  10010024            7        F  20080501.0  20241104
# 1        100373859  10037385            9        F  20120101.0  20241030
# 2       1016611044  10166110           44        F  20140430.0  20241129
# 3        101735213  10173521            3        F  20140507.0  20241121
# 4       1020101730  10201017           30        F  20140428.0  20241112
# ...            ...       ...          ...      ...         ...       ...
# 410844    99198746   9919874            6        F         NaN  20231018
# 410845    99310683   9931068            3        F         NaN  20241007
# 410846    99310703   9931070            3        F         NaN  20241008
# 410847    99310743   9931074            3        F         NaN  20241007
# 410848    99696784   9969678            4        F         NaN  20241111
#
#         init_fda_dt    fda_dt rept_cod auth_num  ... age_grp sex e_sub    wt  \
# 0          20140313  20241109      EXP      NaN  ...     NaN   M     Y   NaN
# 1          20140326  20241111      EXP      NaN  ...       E   F     Y  64.3
# 2          20140512  20241204      EXP      NaN  ...       A   F     Y   NaN
# 3          20140515  20241217      EXP      NaN  ...       T   M     Y  68.0
# 4          20140528  20241114      EXP      NaN  ...     NaN   M     Y   NaN
# ...             ...       ...      ...      ...  ...     ...  ..   ...   ...
# 410844     20140224  20241018      EXP      NaN  ...     NaN   M     Y   NaN
# 410845     20140227  20241009      EXP      NaN  ...     NaN   F     Y   NaN
# 410846     20140227  20241011      EXP      NaN  ...     NaN   F     Y   NaN
# 410847     20140227  20241010      EXP      NaN  ...     NaN   F     Y   NaN
# 410848     20140306  20241126      EXP      NaN  ...     NaN   M     Y   NaN
#
#        wt_cod   rept_dt to_mfr occp_cod  reporter_country occr_country
# 0         NaN  20241109    NaN       MD                DE           DE
# 1          KG  20241111    NaN       MD                GB           GB
# 2         NaN  20241204    NaN       MD                CA           CA
# 3          KG  20241217    NaN       MD                GB           GB
# 4         NaN  20241114    NaN       HP                CA           CA
# ...       ...       ...    ...      ...               ...          ...
# 410844    NaN  20241018    NaN       MD                CA           CA
# 410845    NaN  20241009    NaN       HP                FR           FR
# 410846    NaN  20241011    NaN       HP                FR           FR
# 410847    NaN  20241010    NaN       HP                FR           FR
# 410848    NaN  20241126    NaN       MD                FI           FI
#
# [410849 rows x 25 columns]

# %%
drug_df
# Out:
#          primaryid    caseid  drug_seq role_cod  \
# 0        100100247  10010024         1       PS
# 1        100100247  10010024         2       SS
# 2        100100247  10010024         3       SS
# 3        100100247  10010024         4       SS
# 4        100100247  10010024         5       SS
# ...            ...       ...       ...      ...
# 2030933   99696784   9969678        12       SS
# 2030934   99696784   9969678        13       SS
# 2030935   99696784   9969678        14        C
# 2030936   99696784   9969678        15        C
# 2030937   99696784   9969678        16        C
#
#                                 drugname                          prod_ai  \
# 0                             ADALIMUMAB                       ADALIMUMAB
# 1                             ADALIMUMAB                       ADALIMUMAB
# 2                           CYCLOSPORINE                     CYCLOSPORINE
# 3                               REMICADE                       INFLIXIMAB
# 4                             ETANERCEPT                       ETANERCEPT
# ...                                  ...                              ...
# 2030933                       DAPTOMYCIN                       DAPTOMYCIN
# 2030934         PANTOPRAZOLE SODIUM I.V.              PANTOPRAZOLE SODIUM
# 2030935  ACETAMINOPHEN\CODEINE PHOSPHATE  ACETAMINOPHEN\CODEINE PHOSPHATE
# 2030936               METHYLPREDNISOLONE               METHYLPREDNISOLONE
# 2030937               METHYLPREDNISOLONE               METHYLPREDNISOLONE
#
#          val_vbm                                  route  \
# 0              1                           Subcutaneous
# 1              1                                    NaN
# 2              1                                Unknown
# 3              1  Intravenous (not otherwise specified)
# 4              1                           Subcutaneous
# ...          ...                                    ...
# 2030933        1                                Unknown
# 2030934        1                                Unknown
# 2030935        1                                Unknown
# 2030936        1                                Unknown
# 2030937        1                                Unknown
#
#                                 dose_vbm  cum_dose_chr cum_dose_unit dechal  \
# 0                                    NaN           NaN           NaN      Y
# 1                                    NaN           NaN           NaN      Y
# 2                                    NaN           NaN           NaN      D
# 3        6 infusions at 8 weeks interval           NaN           NaN      Y
# 4                                    NaN           NaN           NaN      Y
# ...                                  ...           ...           ...    ...
# 2030933                    500 mg, Daily           NaN           NaN      Y
# 2030934                       40 mg, UNK           NaN           NaN      U
# 2030935                 500/30 mg, daily           NaN           NaN      Y
# 2030936                       80 mg, bid           NaN           NaN      Y
# 2030937                    12 mg, UNK ()           NaN           NaN      Y
#
#         rechal        lot_num  exp_dt   nda_num  dose_amt dose_unit  \
# 0          NaN  Not Available     NaN  125057.0      40.0        MG
# 1          NaN            NaN     NaN  125057.0       NaN       NaN
# 2          NaN  Not Available     NaN   65003.0       NaN       NaN
# 3          NaN  Not Available     NaN       NaN       NaN       NaN
# 4          NaN  Not Available     NaN       NaN     100.0        MG
# ...        ...            ...     ...       ...       ...       ...
# 2030933    NaN            NaN     NaN       NaN     500.0        MG
# 2030934      U            unk     NaN       NaN      40.0        MG
# 2030935    NaN            NaN     NaN       NaN       NaN       NaN
# 2030936    NaN            NaN     NaN       NaN      80.0        MG
# 2030937    NaN            NaN     NaN       NaN       NaN       NaN
#
#          dose_form dose_freq
# 0              NaN       QOW
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       /WK
# ...            ...       ...
# 2030933        NaN       NaN
# 2030934  Injection       NaN
# 2030935        NaN       NaN
# 2030936        NaN      Q12H
# 2030937        NaN       NaN
#
# [2030938 rows x 20 columns]
# Warning: total number of rows (2030938) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
drug_df.columns
# Out:
# Index(['primaryid', 'caseid', 'drug_seq', 'role_cod', 'drugname', 'prod_ai',
#        'val_vbm', 'route', 'dose_vbm', 'cum_dose_chr', 'cum_dose_unit',
#        'dechal', 'rechal', 'lot_num', 'exp_dt', 'nda_num', 'dose_amt',
#        'dose_unit', 'dose_form', 'dose_freq'],
#       dtype='object')

# %%
indi_df
# Out:
#          primaryid    caseid  indi_drug_seq  \
# 0        100100247  10010024              1
# 1        100100247  10010024              2
# 2        100100247  10010024              3
# 3        100100247  10010024              4
# 4        100100247  10010024              5
# ...            ...       ...            ...
# 1219754   99696784   9969678             12
# 1219755   99696784   9969678             13
# 1219756   99696784   9969678             14
# 1219757   99696784   9969678             15
# 1219758   99696784   9969678             16
#
#                                      indi_pt
# 0                                  Psoriasis
# 1                                  Psoriasis
# 2                                  Psoriasis
# 3                                  Psoriasis
# 4                                  Psoriasis
# ...                                      ...
# 1219754  Product used for unknown indication
# 1219755  Product used for unknown indication
# 1219756  Product used for unknown indication
# 1219757  Product used for unknown indication
# 1219758  Product used for unknown indication
#
# [1219759 rows x 4 columns]

# %%
outc_df
# Out:
#          primaryid    caseid outc_cod
# 0        100100247  10010024       OT
# 1        100373859  10037385       DS
# 2        100373859  10037385       OT
# 3       1016611044  10166110       HO
# 4       1016611044  10166110       OT
# ...            ...       ...      ...
# 308955    99310683   9931068       OT
# 308956    99310703   9931070       DE
# 308957    99310703   9931070       OT
# 308958    99310743   9931074       DE
# 308959    99696784   9969678       OT
#
# [308960 rows x 3 columns]

# %%
rpsr_df
# Out:
#        primaryid    caseid rpsr_cod
# 0      243835561  24383556       HP
# 1      243836211  24383621       HP
# 2      243836221  24383622       HP
# 3      243837501  24383750       HP
# 4      243837511  24383751       HP
# ...          ...       ...      ...
# 11622  247999961  24799996      CSM
# 11623  248000321  24800032      CSM
# 11624  248053191  24805319      CSM
# 11625  248305721  24830572       HP
# 11626  248305821  24830582       HP
#
# [11627 rows x 3 columns]

# %%
ther_df
# Out:
#         primaryid    caseid  dsg_drug_seq    start_dt      end_dt    dur  \
# 0       100100247  10010024             1      2007.0         NaN    6.0
# 1       100100247  10010024             3         NaN         NaN    2.0
# 2       100100247  10010024             4         NaN         NaN    5.0
# 3       100100247  10010024             5    200706.0         NaN    NaN
# 4       100100247  10010024             6         NaN         NaN    5.0
# ...           ...       ...           ...         ...         ...    ...
# 561884  990796022   9907960            10  20181227.0         NaN    NaN
# 561885  990796022   9907960            11  20190730.0         NaN    NaN
# 561886  990796022   9907960            12  20220907.0         NaN    NaN
# 561887  990796022   9907960            13  20221018.0         NaN    NaN
# 561888   99198746   9919874             1  20130808.0  20140121.0  167.0
#
#        dur_cod
# 0           YR
# 1          MON
# 2           WK
# 3          NaN
# 4           WK
# ...        ...
# 561884     NaN
# 561885     NaN
# 561886     NaN
# 561887     NaN
# 561888     DAY
#
# [561889 rows x 7 columns]

# %%
# Check for unique drug names
unique_drug_names = drug_df['drugname'].nunique()
print(f"There are {unique_drug_names} unique drug names in the drug_df DataFrame.")
# Out:
# There are 27175 unique drug names in the drug_df DataFrame.

# %%
# Filter drug_df for rows where 'drugname' contains 'prednisolone'
prednisolone_drugs = drug_df[drug_df['drugname'].str.contains('prednisolone', na=False, case=False)]

# Display the filtered DataFrame
prednisolone_drugs
# Out:
#          primaryid    caseid  drug_seq role_cod            drugname  \
# 64       102112834  10211283         3       SS  METHYLPREDNISOLONE
# 152      103853219  10385321         6       SS        PREDNISOLONE
# 153      103853219  10385321         7       SS        PREDNISOLONE
# 155      103853219  10385321         9       SS        PREDNISOLONE
# 312      104651104  10465110         8       SS        PREDNISOLONE
# ...            ...       ...       ...      ...                 ...
# 2030804   98394552   9839455         2       SS  METHYLPREDNISOLONE
# 2030811   98444074   9844407         5       SS        PREDNISOLONE
# 2030812   98444074   9844407         6       SS        PREDNISOLONE
# 2030936   99696784   9969678        15        C  METHYLPREDNISOLONE
# 2030937   99696784   9969678        16        C  METHYLPREDNISOLONE
#
#                     prod_ai  val_vbm    route  \
# 64       METHYLPREDNISOLONE        1  Unknown
# 152            PREDNISOLONE        1     Oral
# 153            PREDNISOLONE        1     Oral
# 155            PREDNISOLONE        1     Oral
# 312            PREDNISOLONE        1     Oral
# ...                     ...      ...      ...
# 2030804  METHYLPREDNISOLONE        1  Unknown
# 2030811        PREDNISOLONE        1  Unknown
# 2030812        PREDNISOLONE        1      NaN
# 2030936  METHYLPREDNISOLONE        1  Unknown
# 2030937  METHYLPREDNISOLONE        1  Unknown
#
#                                                   dose_vbm  cum_dose_chr  \
# 64                                                     UNK           NaN
# 152      Time Interval: 0.33333333 days: Dosage Text: 2...         980.0
# 153                                       60 milligram, qd         980.0
# 155                                       60 milligram, qd           NaN
# 312                        20mg 3 times a day for days1-14           NaN
# ...                                                    ...           ...
# 2030804                                                NaN           NaN
# 2030811                                                UNK           NaN
# 2030812                                                NaN           NaN
# 2030936                                         80 mg, bid           NaN
# 2030937                                      12 mg, UNK ()           NaN
#
#         cum_dose_unit dechal rechal  lot_num  exp_dt  nda_num  dose_amt  \
# 64                NaN      U    NaN      NaN     NaN      NaN       NaN
# 152                MG      D    NaN  Unknown     NaN      NaN      20.0
# 153                MG      D    NaN  Unknown     NaN      NaN      60.0
# 155               NaN      D    NaN  Unknown     NaN  80354.0      60.0
# 312               NaN      U      U      NaN     NaN      NaN       NaN
# ...               ...    ...    ...      ...     ...      ...       ...
# 2030804           NaN      Y    NaN  Unknown     NaN      NaN       NaN
# 2030811           NaN      D    NaN      NaN     NaN      NaN       NaN
# 2030812           NaN      D    NaN      NaN     NaN      NaN       NaN
# 2030936           NaN      Y    NaN      NaN     NaN      NaN      80.0
# 2030937           NaN      Y    NaN      NaN     NaN      NaN       NaN
#
#         dose_unit dose_form dose_freq
# 64            NaN       NaN       NaN
# 152            MG       UNK       NaN
# 153            MG   Unknown        QD
# 155            MG   Unknown        QD
# 312           NaN   Unknown       NaN
# ...           ...       ...       ...
# 2030804       NaN       NaN       NaN
# 2030811       NaN       NaN       NaN
# 2030812       NaN       NaN       NaN
# 2030936        MG       NaN      Q12H
# 2030937       NaN       NaN       NaN
#
# [18255 rows x 20 columns]

# %%
prednisolone_drugs.columns
# Out:
# Index(['primaryid', 'caseid', 'drug_seq', 'role_cod', 'drugname', 'prod_ai',
#        'val_vbm', 'route', 'dose_vbm', 'cum_dose_chr', 'cum_dose_unit',
#        'dechal', 'rechal', 'lot_num', 'exp_dt', 'nda_num', 'dose_amt',
#        'dose_unit', 'dose_form', 'dose_freq'],
#       dtype='object')

# %%
# Count the number of unique drug names in the filtered DataFrame
unique_prednisolone_drugs = prednisolone_drugs['drugname'].nunique()
print(f"There are {unique_prednisolone_drugs} unique drug names containing 'prednisolone'.")

# Display the unique drug names
print("\nUnique drug names containing 'prednisolone':")
print(prednisolone_drugs['drugname'].unique())
# Out:
# There are 66 unique drug names containing 'prednisolone'.
#
# Unique drug names containing 'prednisolone':
# ['METHYLPREDNISOLONE' 'PREDNISOLONE' 'METHYLPREDNISOLONE SODIUM SUCCINATE'
#  'OXYMETAZOLINE HYDROCHLORIDE;PREDNISOLONE SODIUM PHOSPHATE'
#  'OXYMETAZOLINE HYDROCHLORIDE\\PREDNISOLONE SODIUM PHOSPHATE'
#  'METHYLPREDNISOLONE ACEPONATE'
#  'SOLOMET [METHYLPREDNISOLONE SODIUM SUCCINATE]'
#  'METHYLPREDNISOLONE ACETATE' 'METHYLPREDNISOLONE SODIUM PHOSPHATE'
#  'MOXIFLOXACIN\\PREDNISOLONE ACETATE' 'PREDNISOLONE SODIUM PHOSPHATE'
#  'PREDNISOLONE ACETATE'
#  'CISPLATIN\\CYTARABINE\\ETOPOSIDE\\METHYLPREDNISOLONE (ESHAP)'
#  'BROMFENAC;PREDNISOLONE' 'Nepafenac;Prednisolone'
#  'PREDNISOLONE STEAGLATE' 'Bromfenac;Moxifloxacin;Prednisolone'
#  '.ALPHA.-TOCOPHEROL ACETATE\\ALLANTOIN\\LIDOCAINE\\PREDNISOLONE'
#  'PREDNISOLUT [PREDNISOLONE HEMISUCCINATE]'
#  'METHYLPREDNISOLONE;OBINUTUZUMAB' 'LIDOCAINE\\METHYLPREDNISOLONE ACETATE'
#  'PREDSIM [PREDNISOLONE]' 'PREDNISOLONE VALERATE ACETATE'
#  'PREDNISOLONE VALEROACETATE' 'bromfenac/prednisolone/gemfi'
#  'METHYLPREDNISOLONE HEMISUCCINATE'
#  'TOPISOL [METHYLPREDNISOLONE ACEPONATE]' 'PREDNISOLONE SODIUM SUCCINATE'
#  'PREDNISOLONE [PREDNISOLONE ACETATE] [PREDNISOLONE ACETATE]'
#  'METHYLON [METHYLPREDNISOLONE]'
#  'R-M (mini) CHOP (Cyclophosphamide;D oxorubicin;Vincristine;Prednisolone)'
#  'MEDROL [METHYLPREDNISOLONE SODIUM PHOSPHATE]'
#  'PREDNISOLONA [PREDNISOLONE ACETATE]'
#  'LIDOCAINE HYDROCHLORIDE\\METHYLPREDNISOLONE ACETATE'
#  'MD [METHYLPREDNISOLONE]' 'PREDNISOLONE SODIUM METAZOATE'
#  'Prednisolone 5Mg Tab 28 Stride' 'PREDNISOLONE-BROMFENAC'
#  'METHYLON [METHYLPREDNISOLONE ACETATE]' 'PREDNISOLONE F'
#  'SOLUPRED [PREDNISOLONE METASULFOBENZOATE SODI' 'PREDNISOLONE;BROMFENAC'
#  'DERMOL [NEOMYCIN SULFATE;PREDNISOLONE]' 'CORTAN [PREDNISOLONE]'
#  'PHENYLEPHRINE HYDROCHLORIDE\\PREDNISOLONE ACETATE'
#  'Lepicortinolo (prednisolone)' 'PRED [PREDNISOLONE ACETATE]'
#  'PREDNEFRIN FORTE [PREDNISOLONE ACETATE]' 'MOXIFLOXACIN;PREDNISOLONE'
#  ' PREDNISOLONE AC 1% OPHTH SUSP 5ML TALTZ 80MG/ML AUTOINJECTOR SYR 2S;'
#  'Methylprednisolone 10 mg IV' 'PREDNISOLONE AC  '
#  'SCHERIPROCT [CINCHOCAINE HYDROCHLORIDE;PREDNISOLONE CAPROATE]'
#  'METHYLPREDNISOLONE HIKMA 40 mg, powder for solution for injection'
#  'METHYPRED [METHYLPREDNISOLONE ACETATE]'
#  'PREDNISOLONE METASULFOBENZOATE SODIUM'
#  'METHYL PREDNISOLONE SODIUM SUCC 1000 MG' 'Prednisolone eye drops 1%'
#  'PREDNISOLONE SODIUM PHOS' 'METILPREDNISOLONE DOC' 'Methyl Prednisolone '
#  'Prednisolone Pfizer' 'PREDNISOLONE SODIUM METASULFOBENZOATE'
#  'Prednisolone 1 acetate ophthalmic suspension'
#  'DIBUCAINE HYDROCHLORIDE\\PREDNISOLONE' 'PREDNISOLONE SUS 1% OP']

# %%
# Extract the caseid of all prednisolone rows
caseids = prednisolone_drugs['caseid'].unique()

# Filter other tables separately and keep only the rows whose caseid belongs to the above set
demo_sub = demo_df[ demo_df['caseid'].isin(caseids) ].copy()
reac_sub = reac_df[ reac_df['caseid'].isin(caseids) ].copy()
indi_sub = indi_df[ indi_df['caseid'].isin(caseids) ].copy()

# Select useful columns
demo_sub_small = demo_sub[['caseid','age','sex']].copy()
reac_sub_small = reac_sub[['caseid','pt']].copy()
indi_sub_small = indi_sub[['caseid','indi_pt']].copy()

# Merge the child tables (keep only the required columns) with "caseid" as the key
merged_demo_reac = pd.merge(demo_sub_small, reac_sub_small, on='caseid', how='left')
final_merged = pd.merge(merged_demo_reac, indi_sub_small, on='caseid', how='left')

# View the merge results
print("Number of rows after merging:", len(final_merged))
final_merged.head(10)
# Out:
# Number of rows after merging: 5213962
#      caseid   age sex                                          pt  \
# 0  10211283  61.0   F       General physical health deterioration
# 1  10211283  61.0   F       General physical health deterioration
# 2  10211283  61.0   F       General physical health deterioration
# 3  10211283  61.0   F       General physical health deterioration
# 4  10211283  61.0   F  Drug ineffective for unapproved indication
# 5  10211283  61.0   F  Drug ineffective for unapproved indication
# 6  10211283  61.0   F  Drug ineffective for unapproved indication
# 7  10211283  61.0   F  Drug ineffective for unapproved indication
# 8  10211283  61.0   F                             Muscle disorder
# 9  10211283  61.0   F                             Muscle disorder
#
#                    indi_pt
# 0  Antisynthetase syndrome
# 1  Antisynthetase syndrome
# 2  Antisynthetase syndrome
# 3  Antisynthetase syndrome
# 4  Antisynthetase syndrome
# 5  Antisynthetase syndrome
# 6  Antisynthetase syndrome
# 7  Antisynthetase syndrome
# 8  Antisynthetase syndrome
# 9  Antisynthetase syndrome

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate the frequency of each 'indi_pt' value
indi_pt_counts = final_merged['indi_pt'].value_counts()

# Get the top 10 most frequent 'indi_pt' values
top_10_indi_pt = indi_pt_counts.head(10)

# Create a new column 'indi_pt_grouped'
final_merged['indi_pt_grouped'] = final_merged['indi_pt'].apply(lambda x: x if x in top_10_indi_pt.index else 'Other')

# Plot the distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='indi_pt_grouped', data=final_merged, order = final_merged['indi_pt_grouped'].value_counts().index)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Indication (indi_pt)')
plt.ylabel('Count')
plt.title('Distribution of Top 10 Indications and Others')
plt.show()

# %%
# Merge columns with the same caseid
def join_unique(x):
    return "; ".join(sorted(set(x.dropna())))

final_one_row = final_merged.groupby("caseid", as_index=False).agg({
    'age': 'first',
    'sex': 'first',
    'pt': join_unique,
    'indi_pt': join_unique
})

merged_df = final_one_row.copy()

# %%
merged_df
# Out:
#          caseid   age sex                                                 pt  \
# 0       6084787  64.0   M  Blood creatinine increased; Dizziness; Hyperte...
# 1       6254162  67.0   F  Death; Hepatic failure; Hyperammonaemia; Mycob...
# 2       6353136   9.0   M  Blood lactate dehydrogenase increased; C-react...
# 3       6635598  30.0   F  Ascites; Colitis ulcerative; Hepatic cirrhosis...
# 4       6674528  62.0   M  Fungal infection; Mucormycosis; Multiple organ...
# ...         ...   ...  ..                                                ...
# 10188  24795336  67.0   M  Cough; Cytomegalovirus infection reactivation;...
# 10189  24795452  40.0   F  Abdominal discomfort; Abdominal distension; Ab...
# 10190  24795481  40.0   F  C-reactive protein abnormal; C-reactive protei...
# 10191  24795517  84.0   M                  Off label use; Pulmonary embolism
# 10192  24795563   9.0   M  BK virus infection; Cystitis haemorrhagic; Cyt...
#
#                                                  indi_pt
# 0      Product used for unknown indication; Renal tra...
# 1      Immunosuppressant drug therapy; Prophylaxis ag...
# 2      Graft versus host disease; Product used for un...
# 3                                      Immunosuppression
# 4       Immunosuppression; Liver transplant; Prophylaxis
# ...                                                  ...
# 10188                Product used for unknown indication
# 10189  Migraine; Product used for unknown indication;...
# 10190  Migraine; Product used for unknown indication;...
# 10191                            Immune thrombocytopenia
# 10192  Bone marrow conditioning regimen; Cryptosporid...
#
# [10193 rows x 5 columns]

# %%
# Display basic information about the DataFrame
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10193 entries, 0 to 10192
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   caseid   10193 non-null  int64
#  1   age      8008 non-null   float64
#  2   sex      8735 non-null   object
#  3   pt       10193 non-null  object
#  4   indi_pt  10193 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 398.3+ KB

# %%
# Check for missing values
print(merged_df.isnull().sum())
# Out:
# caseid        0
# age        2185
# sex        1458
# pt            0
# indi_pt       0
# dtype: int64

# %%
# Explore the distribution of 'age'
merged_df['age'].plot(kind='hist', bins=20, title='age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Count by different genders
merged_df.groupby('sex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Analyze the relationship between 'age' and 'sex'
plt.figure(figsize=(8, 6))
sns.boxplot(x='sex', y='age', data=merged_df)
plt.title('Age Distribution by Sex')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Group by prod_ai and count the number of adverse event reports for each product
prod_counts = prednisolone_drugs.groupby('prod_ai').size().reset_index(name='report_count')

# View the statistical description to understand the overall distribution
print(prod_counts['report_count'].describe())

# Visualize the distribution of the number of adverse event reports (histogram)
plt.figure(figsize=(10, 6))
sns.histplot(prod_counts['report_count'], bins=50, kde=False)
plt.title("Distribution of Adverse Event Reports by prod_ai")
plt.xlabel("Number of Reports")
plt.ylabel("Frequency")
plt.show()

# Plot a bar chart of the top 20 products with the most reported quantities
top20 = prod_counts.sort_values(by='report_count', ascending=False).head(20)
plt.figure(figsize=(10, 8))
sns.barplot(x='report_count', y='prod_ai', data=top20, palette="viridis")
plt.title("Top 20 prod_ai with Highest Adverse Event Reports")
plt.xlabel("Number of Reports")
plt.ylabel("prod_ai")
plt.show()
prod_counts
# Out:
# count      21.000000
# mean      866.190476
# std      2320.684783
# min         1.000000
# 25%         3.000000
# 50%        13.000000
# 75%       121.000000
# max      8897.000000
# Name: report_count, dtype: float64
# <ipython-input-100-a3af16d6bbc6>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='report_count', y='prod_ai', data=top20, palette="viridis")
#                                               prod_ai  report_count
# 0   .ALPHA.-TOCOPHEROL ACETATE\ALLANTOIN\LIDOCAINE...             1
# 1   CISPLATIN\CYTARABINE\ETOPOSIDE\METHYLPREDNISOL...             7
# 2                DIBUCAINE HYDROCHLORIDE\PREDNISOLONE             1
# 3   LIDOCAINE HYDROCHLORIDE\METHYLPREDNISOLONE ACE...             3
# 4                LIDOCAINE\METHYLPREDNISOLONE ACETATE             1
# 5                                  METHYLPREDNISOLONE          6430
# 6                        METHYLPREDNISOLONE ACEPONATE            18
# 7                          METHYLPREDNISOLONE ACETATE           827
# 8                    METHYLPREDNISOLONE HEMISUCCINATE             3
# 9                 METHYLPREDNISOLONE SODIUM PHOSPHATE            46
# 10                METHYLPREDNISOLONE SODIUM SUCCINATE          1476
# 11                  MOXIFLOXACIN\PREDNISOLONE ACETATE             1
# 12  OXYMETAZOLINE HYDROCHLORIDE\PREDNISOLONE SODIU...            13
# 13   PHENYLEPHRINE HYDROCHLORIDE\PREDNISOLONE ACETATE             3
# 14                                       PREDNISOLONE          8897
# 15                               PREDNISOLONE ACETATE           292
# 16                      PREDNISOLONE SODIUM METAZOATE            22
# 17                      PREDNISOLONE SODIUM PHOSPHATE           121
# 18                      PREDNISOLONE SODIUM SUCCINATE            21
# 19                             PREDNISOLONE STEAGLATE             2
# 20                      PREDNISOLONE VALERATE ACETATE             5

# %%
# Group by drugname and count the number of adverse event reports for each product
prod_counts = prednisolone_drugs.groupby('drugname').size().reset_index(name='report_count')

# View the statistical description to understand the overall distribution
print(prod_counts.sort_values(by='report_count', ascending=False))

# Visualize the distribution of the number of adverse event reports (histogram)
plt.figure(figsize=(10, 6))
sns.histplot(prod_counts['report_count'], bins=50, kde=False)
plt.title("Distribution of Adverse Event Reports by drugname")
plt.xlabel("Number of Reports")
plt.ylabel("Frequency")
plt.show()

# Plot a bar chart of the top 20 products with the most reported quantities
top20 = prod_counts.sort_values(by='report_count', ascending=False).head(20)
plt.figure(figsize=(10, 8))
sns.barplot(x='report_count', y='drugname', data=top20, palette="viridis")
plt.title("Top 20 drugname with Highest Adverse Event Reports")
plt.xlabel("Number of Reports")
plt.ylabel("drugname")
plt.show()
# Out:
#                                              drugname  report_count
# 37                                       PREDNISOLONE          8897
# 16                                 METHYLPREDNISOLONE          6430
# 22                METHYLPREDNISOLONE SODIUM SUCCINATE          1476
# 18                         METHYLPREDNISOLONE ACETATE           827
# 39                               PREDNISOLONE ACETATE           292
# ..                                                ...           ...
# 59                          Prednisolone eye drops 1%             1
# 61  SCHERIPROCT [CINCHOCAINE HYDROCHLORIDE;PREDNIS...             1
# 63      SOLUPRED [PREDNISOLONE METASULFOBENZOATE SODI             1
# 64             TOPISOL [METHYLPREDNISOLONE ACEPONATE]             1
# 65                       bromfenac/prednisolone/gemfi             1
#
# [66 rows x 2 columns]
# <ipython-input-108-efea5b984fb3>:25: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='report_count', y='drugname', data=top20, palette="viridis")
